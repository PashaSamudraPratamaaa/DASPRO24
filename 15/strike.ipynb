# %%
import pandas as pd
df = pd.read_csv("strike_data.csv")
df
# Out:
#            Date                                        Description   Province  \
# 0    2021-08-30  Workers protest against wage arrears in Xian, ...        陕西省
# 1    2021-08-29  Workers protest against wage arrears of a cons...       黑龙江省
# 2    2021-08-28  Taxi drivers protest against shared electric b...        山西省
# 3    2021-08-28  Workers protest against wage arrears of a cons...        陕西省
# 4    2021-08-27  Workers protest against wage arrears of a cons...        广东省
# ..          ...                                                ...        ...
# 464  2021-03-01  Workers protest against wage arrears of a cons...    Guizhou
# 465  2021-03-01  Workers protest against wage arrears of a cons...    Guizhou
# 466  2021-03-01  Meituan food delivery workers protest against ...  Guangdong
# 467  2021-03-01  Meituan food delivery workers go on strike to ...   Zhejiang
# 468  2021-03-01  Taxi drivers protest against illegal cabs near...      Henan
#
# ...

# %% [markdown]
# <table border="1" cellpadding="8" cellspacing="0">
#   <thead>
#     <tr>
#       <th>No.</th>
#       <th>Skenario Insight / Analisis</th>
#       <th>Penjelasan</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>Jumlah aksi berdasarkan <strong>provinsi/kota</strong></td>
#       <td>Mengidentifikasi wilayah dengan tingkat aksi tertinggi.</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Aksi berdasarkan <strong>jenis industri</strong></td>
#       <td>Melihat sektor industri yang paling sering mengalami konflik buruh.</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>Distribusi aksi menurut <strong>jenis kepemilikan perusahaan</strong></td>
#       <td>Apakah lebih banyak terjadi di perusahaan swasta, BUMN, atau lainnya.</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td><strong>Jenis aksi</strong> yang paling sering dilakukan</td>
#       <td>Apakah aksi dominan berupa protes, mogok kerja, atau gabungan.</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>Jumlah aksi berdasarkan <strong>jumlah partisipan</strong></td>
#       <td>Melihat seberapa besar skala aksi yang terjadi.</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>Kategori <strong>tuntutan buruh</strong> yang paling umum</td>
#       <td>Misalnya, apakah dominan soal upah, jam kerja, atau manajemen.</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td><strong>Respon</strong> terhadap aksi kolektif</td>
#       <td>Apakah manajemen, pemerintah, atau tidak ada respon.</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td><strong>Tren waktu</strong>: frekuensi aksi dari waktu ke waktu</td>
#       <td>Apakah ada peningkatan di bulan/tahun tertentu.</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>Hubungan antara <strong>jenis industri</strong> dan <strong>jenis tuntutan</strong></td>
#       <td>Misalnya, apakah sektor konstruksi selalu berkaitan dengan tunggakan gaji.</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>Korelasi antara <strong>jumlah partisipan</strong> dan <strong>respon yang diberikan</strong></td>
#       <td>Apakah aksi besar lebih mungkin mendapatkan tanggapan pemerintah atau manajemen.</td>
#     </tr>
#   </tbody>
# </table>
